# %% [markdown]
# You are given an integer array nums. You are initially positioned at the array's first index, and each element in the array represents your maximum jump length at that position.
#
# Return true if you can reach the last index, or false otherwise.
#
#
#
# Example 1:
#
# Input: nums = [2,3,1,1,4]
# Output: true
# Explanation: Jump 1 step from index 0 to 1, then 3 steps to the last index.
# Example 2:
#
# Input: nums = [3,2,1,0,4]
# Output: false
# Explanation: You will always arrive at index 3 no matter what. Its maximum jump length is 0, which makes it impossible to reach the last index.
#
#
# Constraints:
#
# 1 <= nums.length <= 104
# 0 <= nums[i] <= 105

# %%
# !pip install typing
from typing import List

# %%
# initial attempt (attempting recursion)
class Solution:
    def canJump(self, nums: List[int]) -> bool:
      pointer = 0
      def helper(pointer, nums):
        return_val = False
        possible_jumps = nums[pointer]
        if(len(nums) == 1):
          return True
        if(pointer == len(nums) - 1):
          return True
        if(possible_jumps + pointer >= len(nums)-1):
          return True
        else:
          if(nums[pointer] == 0):
            return False
          else:
            pointer = pointer + possible_jumps-1
            return_val = helper(pointer, nums)
        return return_val
      return helper(pointer, nums)
##Does not work
##This problem does not have an efficient recursion solution. most recursive solutions come out to O(2^n) or worse:
## Here is a sample of an inefficient but correct solution:

class Solution:
    def canJump(self, nums: List[int]) -> bool:
        def helper(index):
            # Base case: if we reach or exceed the last index, we can finish the game
            if index >= len(nums) - 1:
                return True
            # If the current position has 0 jump length and we're not at the end, it's a dead end
            if nums[index] == 0:
                return False
            # Explore all possible jumps from this position
            max_jump = nums[index]
            for jump in range(1, max_jump + 1):
                # Recursively check if we can reach the end from the next position
                if helper(index + jump):
                    return True
            # If no jump from this position can reach the end, return False
            return False
        # Start the recursion from the first index
        return helper(0)

# %%
#Correct code (done with help of solutions) -- Took > 25 min
class Solution:
    def canJump(self, nums: List[int]) -> bool:
        potential = 0
        for n in nums:
            if potential < 0:
                return False
            elif n > potential:
                potential = n
            potential -= 1

        return True

# %% [markdown]
# Think of the list as a distance that a car has to travel. The car starts with a gasoline amount (the potential of movement) of 0 and at each position it has the option to "refuel" with the amount in nums[i]. every time the car shifts up the road we decrease its gas by 1. At any time we can have a gas of 0 as long as moving up allows for refueling. If not return False

# %% [markdown]
# RESULTS:

# %% [markdown]
# ![Screenshot 2025-01-12 at 5.12.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# SCARTCH WORK

# %%
x = [2, 3, 1, 1, 4]
x[:2]
# Out:
# [2, 3]
