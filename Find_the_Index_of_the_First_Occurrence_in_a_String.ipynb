# %%
class Solution:
    def strStr(self, haystack: str, needle: str) -> int:
        if(needle not in haystack):
          return -1
        else:
          return haystack.index(needle)

# %% [markdown]
# ![Screenshot 2025-01-19 at 7.16.10 PM.png](data:image/png;base64,...)

# %%
str1 = "HelloBigBoy"
str1.index("Boi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d5df943f851c> in <cell line: 0>()
#       1 str1 = "HelloBigBoy"
# ----> 2 str1.index("Boi")
#
# ValueError: substring not found
